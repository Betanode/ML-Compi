# %%
import pandas as pd

# %%
data = pd.read_csv("train.csv")

# %%
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
test = pd.read_csv("test.csv")

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
p = data.fillna("AA")

# %%
q = test.fillna("AA")

# %%
from sklearn.preprocessing import OrdinalEncoder
orcode = OrdinalEncoder()

# %%
train = orcode.fit_transform(p[["MSZoning" , "Street" ,"Alley" , "LotShape" , "LandContour" ,"Utilities","LotConfig","LandSlope"  , "Neighborhood" , "Condition1" , "Condition2" , "BldgType" , "HouseStyle" , "RoofStyle" , "RoofMatl" , "Exterior1st" , "Exterior2nd" , "MasVnrType" , "ExterQual" , "ExterCond" , "Foundation" , "BsmtQual" , "BsmtCond" , "BsmtExposure" , "BsmtFinType1" , "BsmtFinType2" , "Heating" , "HeatingQC" , "CentralAir" , "Electrical" , "KitchenQual" , "Functional" , "FireplaceQu" , "GarageType" , "GarageFinish" , "GarageQual" , "GarageCond" , "PavedDrive" , "PoolQC" , "Fence" , "MiscFeature" , "SaleType" , "SaleCondition"]])[:1460]

# %%
t = pd.DataFrame(train , columns = ["MSZoning" , "Street" ,"Alley" , "LotShape" , "LandContour" ,"Utilities","LotConfig","LandSlope"  , "Neighborhood" , "Condition1" , "Condition2" , "BldgType" , "HouseStyle" , "RoofStyle" , "RoofMatl" , "Exterior1st" , "Exterior2nd" , "MasVnrType" , "ExterQual" , "ExterCond" , "Foundation" , "BsmtQual" , "BsmtCond" , "BsmtExposure" , "BsmtFinType1" , "BsmtFinType2" , "Heating" , "HeatingQC" , "CentralAir" , "Electrical" , "KitchenQual" , "Functional" , "FireplaceQu" , "GarageType" , "GarageFinish" , "GarageQual" , "GarageCond" , "PavedDrive" , "PoolQC" , "Fence" , "MiscFeature" , "SaleType" , "SaleCondition"])

# %%
t
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0          3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 1          3.0     1.0    0.0       3.0          3.0        0.0        2.0
# 2          3.0     1.0    0.0       0.0          3.0        0.0        4.0
# 3          3.0     1.0    0.0       0.0          3.0        0.0        0.0
# 4          3.0     1.0    0.0       0.0          3.0        0.0        2.0
# ...        ...     ...    ...       ...          ...        ...        ...
# 1455       3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 1456       3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 1457       3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 1458       3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 1459       3.0     1.0    0.0       3.0          3.0        0.0        4.0
#
# ...

# %%
t["Id"] = data['Id']
t["MSSubClass"] = data['MSSubClass']
t["LotFrontage"] = data['LotFrontage']
t["LotArea"] = data['LotArea']
t["OverallQual"] = data['OverallQual']
t["OverallCond"] = data['OverallCond']
t["YearBuilt"] = data['YearBuilt']
t["YearRemodAdd"] = data['YearRemodAdd']
t["MasVnrArea"] = data['MasVnrArea']
t["BsmtFinSF1"] = data['BsmtFinSF1']
t["BsmtUnfSF"] = data['BsmtUnfSF']
t["TotalBsmtSF"] = data['TotalBsmtSF']
t["1stFlrSF"] = data['1stFlrSF']
t["2ndFlrSF"] = data['2ndFlrSF']
t["LowQualFinSF"] = data['LowQualFinSF']
t["GrLivArea"] = data['GrLivArea']
t["BsmtFullBath"] = data['BsmtFullBath']
t["BsmtHalfBath"] = data['BsmtHalfBath']
t["FullBath"] = data['FullBath']
t["HalfBath"] = data['HalfBath']
t["BedroomAbvGr"] = data['BedroomAbvGr']
t["KitchenAbvGr"] = data['KitchenAbvGr']
t["TotRmsAbvGrd"] = data['TotRmsAbvGrd']
t["Fireplaces"] = data['Fireplaces']
t["GarageCars"] = data['GarageCars']
t["GarageArea"] = data['GarageArea']
t["WoodDeckSF"] = data['WoodDeckSF']
t["OpenPorchSF"] = data['OpenPorchSF']
t["EnclosedPorch"] = data['EnclosedPorch']
t["3SsnPorch"] = data['3SsnPorch']
t["ScreenPorch"] = data['ScreenPorch']
t["PoolArea"] = data['PoolArea']
t["MiscVal"] = data['MiscVal']
t["MoSold"] = data['MoSold']
t["YrSold"] = data['YrSold']

# %%
t.head(15)
# Out:
#     MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0        3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 1        3.0     1.0    0.0       3.0          3.0        0.0        2.0
# 2        3.0     1.0    0.0       0.0          3.0        0.0        4.0
# 3        3.0     1.0    0.0       0.0          3.0        0.0        0.0
# 4        3.0     1.0    0.0       0.0          3.0        0.0        2.0
# 5        3.0     1.0    0.0       0.0          3.0        0.0        4.0
# 6        3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 7        3.0     1.0    0.0       0.0          3.0        0.0        0.0
# 8        4.0     1.0    0.0       3.0          3.0        0.0        4.0
# 9        3.0     1.0    0.0       3.0          3.0        0.0        0.0
# 10       3.0     1.0    0.0       3.0          3.0        0.0        4.0
# 11       3.0     1.0    0.0       0.0          3.0        0.0        4.0
# ...

# %%
test_oe = orcode.fit_transform(q[["MSZoning" , "Street" ,"Alley" , "LotShape" , "LandContour" ,"Utilities","LotConfig","LandSlope"  , "Neighborhood" , "Condition1" , "Condition2" , "BldgType" , "HouseStyle" , "RoofStyle" , "RoofMatl" , "Exterior1st" , "Exterior2nd" , "MasVnrType" , "ExterQual" , "ExterCond" , "Foundation" , "BsmtQual" , "BsmtCond" , "BsmtExposure" , "BsmtFinType1" , "BsmtFinType2" , "Heating" , "HeatingQC" , "CentralAir" , "Electrical" , "KitchenQual" , "Functional" , "FireplaceQu" , "GarageType" , "GarageFinish" , "GarageQual" , "GarageCond" , "PavedDrive" , "PoolQC" , "Fence" , "MiscFeature" , "SaleType" , "SaleCondition"]])[:1460]

# %%
te = pd.DataFrame(test_oe , columns = ["MSZoning" , "Street" ,"Alley" , "LotShape" , "LandContour" ,"Utilities","LotConfig","LandSlope"  , "Neighborhood" , "Condition1" , "Condition2" , "BldgType" , "HouseStyle" , "RoofStyle" , "RoofMatl" , "Exterior1st" , "Exterior2nd" , "MasVnrType" , "ExterQual" , "ExterCond" , "Foundation" , "BsmtQual" , "BsmtCond" , "BsmtExposure" , "BsmtFinType1" , "BsmtFinType2" , "Heating" , "HeatingQC" , "CentralAir" , "Electrical" , "KitchenQual" , "Functional" , "FireplaceQu" , "GarageType" , "GarageFinish" , "GarageQual" , "GarageCond" , "PavedDrive" , "PoolQC" , "Fence" , "MiscFeature" , "SaleType" , "SaleCondition"])

# %%
te
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0          3.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1          4.0     1.0    0.0       0.0          3.0        1.0        0.0
# 2          4.0     1.0    0.0       0.0          3.0        1.0        4.0
# 3          4.0     1.0    0.0       0.0          3.0        1.0        4.0
# 4          4.0     1.0    0.0       0.0          1.0        1.0        4.0
# ...        ...     ...    ...       ...          ...        ...        ...
# 1454       5.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1455       5.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1456       4.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1457       4.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1458       4.0     1.0    0.0       3.0          3.0        1.0        4.0
#
# ...

# %%
te["Id"] = test['Id']
te["MSSubClass"] = test['MSSubClass']
te["LotFrontage"] = test['LotFrontage']
te["LotArea"] = test['LotArea']
te["OverallQual"] = test['OverallQual']
te["OverallCond"] = test['OverallCond']
te["YearBuilt"] = test['YearBuilt']
te["YearRemodAdd"] = test['YearRemodAdd']
te["MasVnrArea"] = test['MasVnrArea']
te["BsmtFinSF1"] = test['BsmtFinSF1']
te["BsmtUnfSF"] = test['BsmtUnfSF']
te["TotalBsmtSF"] = test['TotalBsmtSF']
te["1stFlrSF"] = test['1stFlrSF']
te["2ndFlrSF"] = test['2ndFlrSF']
te["LowQualFinSF"] = test['LowQualFinSF']
te["GrLivArea"] = test['GrLivArea']
te["BsmtFullBath"] = test['BsmtFullBath']
te["BsmtHalfBath"] = test['BsmtHalfBath']
te["FullBath"] = test['FullBath']
te["HalfBath"] = test['HalfBath']
te["BedroomAbvGr"] = test['BedroomAbvGr']
te["KitchenAbvGr"] = test['KitchenAbvGr']
te["TotRmsAbvGrd"] = test['TotRmsAbvGrd']
te["Fireplaces"] = test['Fireplaces']
te["GarageCars"] = test['GarageCars']
te["GarageArea"] = test['GarageArea']
te["WoodDeckSF"] = test['WoodDeckSF']
te["OpenPorchSF"] = test['OpenPorchSF']
te["EnclosedPorch"] = test['EnclosedPorch']
te["3SsnPorch"] = test['3SsnPorch']
te["ScreenPorch"] = test['ScreenPorch']
te["PoolArea"] = test['PoolArea']
te["MiscVal"] = test['MiscVal']
te["MoSold"] = test['MoSold']
te["YrSold"] = test['YrSold']

# %%
te
# Out:
#       MSZoning  Street  Alley  LotShape  LandContour  Utilities  LotConfig  \
# 0          3.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1          4.0     1.0    0.0       0.0          3.0        1.0        0.0
# 2          4.0     1.0    0.0       0.0          3.0        1.0        4.0
# 3          4.0     1.0    0.0       0.0          3.0        1.0        4.0
# 4          4.0     1.0    0.0       0.0          1.0        1.0        4.0
# ...        ...     ...    ...       ...          ...        ...        ...
# 1454       5.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1455       5.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1456       4.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1457       4.0     1.0    0.0       3.0          3.0        1.0        4.0
# 1458       4.0     1.0    0.0       3.0          3.0        1.0        4.0
#
# ...

# %%
y = data["SalePrice"]

# %%
t.isnull().any()
# Out:
# MSZoning       False
# Street         False
# Alley          False
# LotShape       False
# LandContour    False
#                ...
# ScreenPorch    False
# PoolArea       False
# MiscVal        False
# MoSold         False
# YrSold         False
# Length: 78, dtype: bool

# %%
te.isnull().any()
# Out:
# MSZoning       False
# Street         False
# Alley          False
# LotShape       False
# LandContour    False
#                ...
# ScreenPorch    False
# PoolArea       False
# MiscVal        False
# MoSold         False
# YrSold         False
# Length: 78, dtype: bool

# %%
te = te.fillna(0)

# %%
t = t.fillna(0)

# %%
from sklearn.linear_model import Ridge

# %%
from sklearn import linear_model
cl = linear_model.Lasso(alpha=0.1)
cl.fit(t,y)
y_ = cl.predict(te)

# %%
y_.size
# Out:
# 1459

# %%
d = pd.DataFrame(y_)
d.to_csv("p2.csv")

# %%
clf = Ridge(alpha=1.0)

# %%
clf.fit(t,y)
# Out:
# Ridge()

# %%
y_predict  = clf.predict(te)

# %%
y_predict.size
# Out:
# 1459

# %%
df = pd.DataFrame(y_predict)

# %%
df
# Out:
#                   0
# 0      83783.772072
# 1     133511.308066
# 2     141617.669876
# 3     161183.724112
# 4     160507.075659
# ...             ...
# 1454   49728.716626
# 1455   27897.247643
# 1456  127812.053608
# 1457   92151.478512
# 1458  214511.824332
#
# [1459 rows x 1 columns]

# %%
df.to_csv("predicted.csv")
